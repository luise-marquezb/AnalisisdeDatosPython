# %% [markdown]
# # **LIBRERIAS A UTILIZAR**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# #  **CARGA DE DATOS**

# %%
df1 = pd.read_excel('data.xls')

df2 = pd.read_csv('dataCGP.csv')

df1
# Out:
#     Impacto     Circuito Servicio            Motivo  \
# 0      Alto        Bello     Agua  Lavado de tanque
# 1      Alto       Itagüí     Agua  Lavado de tanque
# 2      Alto        Moscú     Agua     Modernización
# 3      Alto        Aures     Agua     Modernización
# 4      Alto  Santa Elena     Agua  Lavado de tanque
# ..      ...          ...      ...               ...
# 951    Alto        Bello     Agua     Modernización
# 952    Alto       Centro     Agua     Modernización
# 953    Alto       Berlín     Agua     Modernización
# 954    Alto       Berlín     Agua  Lavado de tanque
# 955    Bajo  Villa Linda     Agua  Lavado de tanque
#
#                                               Solicita  Instalacion Municipio  \
# 0       Unidad Operación Mantenimiento Provisión Aguas        47412     Bello
# 1       Unidad Operación Mantenimiento Provisión Aguas        36127    Itagüí
# 2     Unidad Gestión Infraestructura Agua y Saneamient        17606  Medellín
# 3      Unidad Desarrollo de Intervenciones de Inversió        16504  Medellín
# 4       Unidad Operación Mantenimiento Provisión Aguas        14074  Medellín
# ..                                                 ...          ...       ...
# 951  Dirección Proyectos Agua, Saneamiento, Gas y l...        45710     Bello
# 952     Unidad Operación Mantenimiento Provisión Aguas         2245  Rionegro
# 953     Unidad Operación Mantenimiento Provisión Aguas         4928  Medellín
# 954     Unidad Operación Mantenimiento Provisión Aguas         8610  Medellín
# 955     Unidad Operación Mantenimiento Provisión Aguas          568     Bello
#
#                                              Dirección  \
# 0    De CL 44 hasta CL 55 entre CR 43 y CR 59, De C...
# 1    De CL 26 hasta CL 46 entre CR 40 y CR 42; De C...
# 2    De Calle 78 hasta calle 81 entre carrera 39 y ...
# 3    De Calle 80A hasta calle 83 entre carrera 89A ...
# 4    De Calle 49A hasta calle 52 entre carrera 2C y...
# ..                                                 ...
# 951  De CL 87 hasta CL 90 entre CR 46 y CR 50A; De ...
# 952              De CL47 hasta CL60 entre CR54 y CR 57
# 953            De CL86 hasta CL98 entre CR49 y CR 50 A
# 954  De CL 87 hasta CL 89 entre CR 46A y CR 50A; De...
# 955       De CL 81C hasta CL 84B entre CR 66B y CR 67C
#
#           Nombre del responsable   Fecha y hora esperada  \
# 0    Jorge Humberto Marin Posada  07/29/2021 04:00:00 AM
# 1    Jorge Humberto Marin Posada  07/25/2019 04:00:00 AM
# 2    Jorge Humberto Marin Posada  08/13/2021 01:00:00 AM
# 3    Jorge Humberto Marin Posada  12/13/2021 04:00:00 AM
# 4    Jorge Humberto Marin Posada  12/12/2021 05:00:00 AM
# ..                           ...                     ...
# 951          Yaneth Moreno Vélez  02/02/2020 05:00:00 AM
# 952       Julio César Rúa Arango  01/28/2020 08:00:00 PM
# 953       Julio César Rúa Arango  01/28/2020 05:30:00 PM
# 954  Jorge Humberto Marin Posada  01/28/2020 04:00:00 AM
# 955  Jorge Humberto Marin Posada  01/28/2020 03:00:00 PM
#
#                      Inicio                     Fin  Horas  ABIERTA  \
# 0    07/28/2021 07:00:00 PM  07/29/2021 04:00:00 AM    9.0  ABIERTA
# 1    07/24/2019 07:00:00 PM  07/25/2019 04:00:00 AM    9.0  ABIERTA
# 2    08/12/2021 04:00:00 PM  08/13/2021 01:00:00 AM    9.0  ABIERTA
# 3    12/15/2021 07:00:00 PM  12/16/2021 04:00:00 AM    9.0  ABIERTA
# 4    11/22/2021 08:00:00 PM  11/23/2021 05:00:00 AM    9.0  ABIERTA
# ..                      ...                     ...    ...      ...
# 951  02/01/2020 03:00:00 PM  02/02/2020 05:00:00 AM   14.0  ABIERTA
# 952  01/28/2020 08:00:00 AM  01/28/2020 08:00:00 PM   12.0  ABIERTA
# 953  01/27/2020 05:30:00 PM  01/28/2020 02:30:00 AM    9.0  ABIERTA
# 954  01/27/2020 09:00:00 PM  01/28/2020 04:00:00 AM    7.0  ABIERTA
# 955  01/28/2020 10:00:00 AM  01/28/2020 03:00:00 PM    5.0  ABIERTA
#
#           Fecha de registro  \
# 0    07/21/2021 12:00:00 AM
# 1    07/18/2019 12:00:00 AM
# 2    08/02/2021 12:00:00 AM
# 3    12/01/2021 12:00:00 AM
# 4    11/16/2021 12:00:00 AM
# ..                      ...
# 951  01/17/2020 12:00:00 AM
# 952  01/20/2020 12:00:00 AM
# 953  01/13/2020 12:00:00 AM
# 954  01/21/2020 12:00:00 AM
# 955  01/21/2020 12:00:00 AM
#
#                                            Explicación  \
# 0    Instalaciones afectadas: 47412 | Motivo: Lavad...
# 1    Instalaciones afectadas: 36127 | Motivo: Lavad...
# 2    Instalaciones afectadas: 17606 | Motivo: Empal...
# 3    Instalaciones afectadas: 16504 | Motivo: Empal...
# 4    Instalaciones afectadas: 14074 | Motivo: Lavad...
# ..                                                 ...
# 951  Instalaciones afectadas: 45710 | Motivo: Empal...
# 952  Instalaciones afectadas: 2245 | Motivo: Empalm...
# 953  Instalaciones afectadas: 4928 | Motivo: Empalm...
# 954  Instalaciones afectadas: 8610 | Motivo: Lavado...
# 955  Instalaciones afectadas: 568 | Motivo: Lavado ...
#
#                                                 Barrio  \
# 0    ZONA INDUSTRIAL 3 (BELLO);PANAMERICANO;CIUDAD ...
# 1    SANTA CRUZ (ITAGUI);ZONA INDUSTRIAL 2 (ITAGUI)...
# 2    Santo Domingo Savio No. 1; Granizal; Moscú No....
# 3    Aures No. 2; Picacho; Aures No. 1; Monteclaro ...
# 4    La Libertad; Villatina; Villa Lilliam; El Pina...
# ..                                                 ...
# 951  ZONA INDUSTRIAL 3 (BELLO);PANAMERICANO;CIUDAD ...
# 952  LA ESPERANZA, GUILLERMO GAVIRIA, BELCHITE, CAS...
# 953  LA PINUELA, ARANJUEZ, SAN ISIDRO (MEDELLIN), B...
# 954  SAN ISIDRO (MEDELLIN);LA ROSA;BERLIN;ARANJUEZ;...
# 955                         AREA SIN DLLO COM 04 BELLO
#
#                              Contratista      Tipo de aviso
# 0                 Ingeniería Total Ltda.  IVR + Plan medios
# 1                 Ingeniería Total Ltda.  IVR + Plan medios
# 2            Contratista: PAECIA  S.A.S.  IVR + Plan medios
# 3            Contratista: PAECIA  S.A.S.  IVR + Plan medios
# 4    Contratista: Ingeniería Total Ltda.  IVR + Plan medios
# ..                                   ...                ...
# 951              UT Mejia Acevedo y S&E.  IVR + Plan medios
# 952               Consorcio San Nicolás.                IVR
# 953                         SANEAR S, A.                IVR
# 954               Ingeniería Total Ltda.  IVR + Plan medios
# 955               Ingeniería Total Ltda.                IVR
#
# [956 rows x 19 columns]

# %% [markdown]
# # **INSPECCIÓN DE DATOS**

# %%
df2.describe()
# Out:
#         Cantidad  Precio Unitario       Total
# count  50.000000        50.000000   50.000000
# mean    2.900000        18.400000   51.200000
# std     1.265718         7.521398   30.465102
# min     1.000000        10.000000   10.000000
# 25%     2.000000        10.000000   30.000000
# 50%     3.000000        15.000000   40.000000
# 75%     4.000000        20.000000   60.000000
# max     5.000000        30.000000  150.000000

# %%
df1.dtypes
# Out:
# Impacto                    object
# Circuito                   object
# Servicio                   object
# Motivo                     object
# Solicita                   object
# Instalacion                 int64
# Municipio                  object
# Dirección                  object
# Nombre del responsable     object
# Fecha y hora esperada      object
# Inicio                     object
# Fin                        object
# Horas                     float64
# ABIERTA                    object
# Fecha de registro          object
# Explicación                object
# Barrio                     object
# Contratista                object
# Tipo de aviso              object
# dtype: object

# %%
df2.head(10)
# Out:
#         Fecha    Cliente   Producto  Cantidad  Precio Unitario  Total  \
# 0  2023-11-01   Cliente1  ProductoA         5               10     50
# 1  2023-11-02   Cliente2  ProductoB         3               15     45
# 2  2023-11-03   Cliente3  ProductoC         2               20     40
# 3  2023-11-04   Cliente4  ProductoA         4               10     40
# 4  2023-11-05   Cliente5  ProductoD         1               30     30
# 5  2023-11-06   Cliente6  ProductoB         2               15     30
# 6  2023-11-07   Cliente7  ProductoA         3               10     30
# 7  2023-11-08   Cliente8  ProductoC         2               20     40
# 8  2023-11-09   Cliente9  ProductoD         4               30    120
# 9  2023-11-10  Cliente10  ProductoA         3               10     30
#
#           Origen
# 0         Online
# 1         Online
# 2         Online
# 3  Tienda Física
# 4         Online
# 5         Online
# 6  Tienda Física
# 7         Online
# 8         Online
# 9  Tienda Física

# %%
df1.tail(10)
# Out:
#     Impacto        Circuito Servicio            Motivo  \
# 946    Bajo        Palmitas     Agua     Mantenimiento
# 947    Bajo  Volador Centro     Agua     Modernización
# 948    Bajo   San Cristóbal     Agua     Mantenimiento
# 949    Bajo         América     Agua     Modernización
# 950    Bajo         América     Agua     Modernización
# 951    Alto           Bello     Agua     Modernización
# 952    Alto          Centro     Agua     Modernización
# 953    Alto          Berlín     Agua     Modernización
# 954    Alto          Berlín     Agua  Lavado de tanque
# 955    Bajo     Villa Linda     Agua  Lavado de tanque
#
#                                               Solicita  Instalacion Municipio  \
# 946       Unidad Mantenimiento Equipos Provisión Aguas          198  Medellín
# 947  Dirección Proyectos Aguas, Saneamiento, Gas y ...          190  Medellín
# 948     Unidad Operación Mantenimiento Provisión Aguas           78  Medellín
# 949  Unidad Operación y  Mantenimiento Gestión Agua...           13  Medellín
# 950  Unidad Operación y  Mantenimiento Gestión Agua...           13  Medellín
# 951  Dirección Proyectos Agua, Saneamiento, Gas y l...        45710     Bello
# 952     Unidad Operación Mantenimiento Provisión Aguas         2245  Rionegro
# 953     Unidad Operación Mantenimiento Provisión Aguas         4928  Medellín
# 954     Unidad Operación Mantenimiento Provisión Aguas         8610  Medellín
# 955     Unidad Operación Mantenimiento Provisión Aguas          568     Bello
#
#                                              Dirección  \
# 946  De Rural 146012800000000000  hasta 14601602500...
# 947             De CR77 hasta CR80 entre CL73 y CL 73C
# 948                      CL 63 ENTRE CR 129 A Y CR 130
# 949                        CR 81A ENTRE CL 32 Y CL 32B
# 950                        CR 81A ENTRE CL 32 Y CL 32B
# 951  De CL 87 hasta CL 90 entre CR 46 y CR 50A; De ...
# 952              De CL47 hasta CL60 entre CR54 y CR 57
# 953            De CL86 hasta CL98 entre CR49 y CR 50 A
# 954  De CL 87 hasta CL 89 entre CR 46A y CR 50A; De...
# 955       De CL 81C hasta CL 84B entre CR 66B y CR 67C
#
#           Nombre del responsable   Fecha y hora esperada  \
# 946  Jorge Humberto Marin Posada  07/07/2021 11:00:00 PM
# 947         Claudia Marcela Toro  02/07/2019 06:00:00 PM
# 948         Claudia Marcela Toro  06/06/2019 11:00:00 AM
# 949         Claudia Marcela Toro  06/13/2019 07:00:00 PM
# 950         Claudia Marcela Toro  06/18/2019 07:00:00 PM
# 951          Yaneth Moreno Vélez  02/02/2020 05:00:00 AM
# 952       Julio César Rúa Arango  01/28/2020 08:00:00 PM
# 953       Julio César Rúa Arango  01/28/2020 05:30:00 PM
# 954  Jorge Humberto Marin Posada  01/28/2020 04:00:00 AM
# 955  Jorge Humberto Marin Posada  01/28/2020 03:00:00 PM
#
#                      Inicio                     Fin  Horas  ABIERTA  \
# 946  07/07/2021 01:00:00 PM  07/07/2021 11:00:00 PM   10.0  ABIERTA
# 947  02/07/2019 08:00:00 AM  02/07/2019 06:00:00 PM   10.0  ABIERTA
# 948  06/06/2019 10:00:00 AM  06/06/2019 11:00:00 AM   10.0  ABIERTA
# 949  06/13/2019 09:00:00 AM  06/13/2019 07:00:00 PM   10.0  ABIERTA
# 950  06/18/2019 09:00:00 AM  06/18/2019 07:00:00 PM   10.0  ABIERTA
# 951  02/01/2020 03:00:00 PM  02/02/2020 05:00:00 AM   14.0  ABIERTA
# 952  01/28/2020 08:00:00 AM  01/28/2020 08:00:00 PM   12.0  ABIERTA
# 953  01/27/2020 05:30:00 PM  01/28/2020 02:30:00 AM    9.0  ABIERTA
# 954  01/27/2020 09:00:00 PM  01/28/2020 04:00:00 AM    7.0  ABIERTA
# 955  01/28/2020 10:00:00 AM  01/28/2020 03:00:00 PM    5.0  ABIERTA
#
#           Fecha de registro  \
# 946  06/29/2021 12:00:00 AM
# 947  01/16/2019 12:00:00 AM
# 948  05/29/2019 12:00:00 AM
# 949  06/05/2019 12:00:00 AM
# 950  06/05/2019 12:00:00 AM
# 951  01/17/2020 12:00:00 AM
# 952  01/20/2020 12:00:00 AM
# 953  01/13/2020 12:00:00 AM
# 954  01/21/2020 12:00:00 AM
# 955  01/21/2020 12:00:00 AM
#
#                                            Explicación  \
# 946  Instalaciones afectadas: 198 | Motivo: Cambio ...
# 947  Instalaciones afectadas: 190 | Motivo: Empalme...
# 948  Instalaciones afectadas: 78 | Motivo: Preaisla...
# 949  Instalaciones afectadas: 13 | Motivo: Empalme ...
# 950  Instalaciones afectadas: 13 | Motivo: Empalme ...
# 951  Instalaciones afectadas: 45710 | Motivo: Empal...
# 952  Instalaciones afectadas: 2245 | Motivo: Empalm...
# 953  Instalaciones afectadas: 4928 | Motivo: Empalm...
# 954  Instalaciones afectadas: 8610 | Motivo: Lavado...
# 955  Instalaciones afectadas: 568 | Motivo: Lavado ...
#
#                                                 Barrio  \
# 946                                           PALMITAS
# 947                   FACULTAD DE MINAS UNIV. NACIONAL
# 948                                      SAN CRISTOBAL
# 949                              NUEVA VILLA DE ABURRA
# 950                              NUEVA VILLA DE ABURRA
# 951  ZONA INDUSTRIAL 3 (BELLO);PANAMERICANO;CIUDAD ...
# 952  LA ESPERANZA, GUILLERMO GAVIRIA, BELCHITE, CAS...
# 953  LA PINUELA, ARANJUEZ, SAN ISIDRO (MEDELLIN), B...
# 954  SAN ISIDRO (MEDELLIN);LA ROSA;BERLIN;ARANJUEZ;...
# 955                         AREA SIN DLLO COM 04 BELLO
#
#                                            Contratista      Tipo de aviso
# 946  Unidad Mantenimiento Equipos Provisión Aguas -...                IVR
# 947                            CONSORCIO REDES IGUANÁ.           Volantes
# 948                                        SANEAR S.A.           Volantes
# 949                                      REDYCO S.A.S.           Volantes
# 950                                      REDYCO S.A.S.           Volantes
# 951                            UT Mejia Acevedo y S&E.  IVR + Plan medios
# 952                             Consorcio San Nicolás.                IVR
# 953                                       SANEAR S, A.                IVR
# 954                             Ingeniería Total Ltda.  IVR + Plan medios
# 955                             Ingeniería Total Ltda.                IVR

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Impacto                 956 non-null    object
#  1   Circuito                956 non-null    object
#  2   Servicio                956 non-null    object
#  3   Motivo                  956 non-null    object
#  4   Solicita                956 non-null    object
#  5   Instalacion             956 non-null    int64
#  6   Municipio               956 non-null    object
#  7   Dirección               956 non-null    object
#  8   Nombre del responsable  956 non-null    object
#  9   Fecha y hora esperada   956 non-null    object
#  10  Inicio                  956 non-null    object
#  11  Fin                     956 non-null    object
#  12  Horas                   956 non-null    float64
#  13  ABIERTA                 956 non-null    object
#  14  Fecha de registro       956 non-null    object
#  15  Explicación             956 non-null    object
#  16  Barrio                  956 non-null    object
#  17  Contratista             956 non-null    object
#  18  Tipo de aviso           956 non-null    object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 142.0+ KB

# %% [markdown]
# # **LIMPIEZA DE DATOS**

# %%
df2.isnull().sum()
# Out:
# Fecha              0
# Cliente            0
# Producto           0
# Cantidad           0
# Precio Unitario    0
# Total              0
# Origen             0
# dtype: int64

# %%
df2.rename(columns = {'Precio Unitario':'PRECIO'}, inplace = True)

# %%
df1.rename(columns = {'Horas':'HR', 'Explicación':'EXP'}, inplace = True)

# %%
df2.drop(columns = ['PRECIO'])
# Out:
#          Fecha    Cliente   Producto  Cantidad  Total         Origen
# 0   2023-11-01   Cliente1  ProductoA         5     50         Online
# 1   2023-11-02   Cliente2  ProductoB         3     45         Online
# 2   2023-11-03   Cliente3  ProductoC         2     40         Online
# 3   2023-11-04   Cliente4  ProductoA         4     40  Tienda Física
# 4   2023-11-05   Cliente5  ProductoD         1     30         Online
# 5   2023-11-06   Cliente6  ProductoB         2     30         Online
# 6   2023-11-07   Cliente7  ProductoA         3     30  Tienda Física
# 7   2023-11-08   Cliente8  ProductoC         2     40         Online
# 8   2023-11-09   Cliente9  ProductoD         4    120         Online
# 9   2023-11-10  Cliente10  ProductoA         3     30  Tienda Física
# 10  2023-11-11  Cliente11  ProductoB         5     75         Online
# 11  2023-11-12  Cliente12  ProductoC         2     40         Online
# 12  2023-11-13  Cliente13  ProductoD         1     30  Tienda Física
# 13  2023-11-14  Cliente14  ProductoA         3     30         Online
# 14  2023-11-15  Cliente15  ProductoB         4     60         Online
# 15  2023-11-16  Cliente16  ProductoC         2     40  Tienda Física
# 16  2023-11-17  Cliente17  ProductoD         3     90         Online
# 17  2023-11-18  Cliente18  ProductoA         4     40         Online
# 18  2023-11-19  Cliente19  ProductoB         2     30  Tienda Física
# 19  2023-11-20  Cliente20  ProductoC         3     60         Online
# 20  2023-11-21  Cliente21  ProductoD         1     30         Online
# 21  2023-11-22  Cliente22  ProductoA         5     50  Tienda Física
# 22  2023-11-23  Cliente23  ProductoB         3     45         Online
# 23  2023-11-24  Cliente24  ProductoC         2     40         Online
# 24  2023-11-25  Cliente25  ProductoD         4    120  Tienda Física
# 25  2023-11-26  Cliente26  ProductoA         3     30         Online
# 26  2023-11-27  Cliente27  ProductoB         5     75         Online
# 27  2023-11-28  Cliente28  ProductoC         2     40         Online
# 28  2023-11-29  Cliente29  ProductoD         1     30  Tienda Física
# 29  2023-11-30  Cliente30  ProductoA         2     20         Online
# 30  2023-12-01  Cliente31  ProductoB         4     60         Online
# 31  2023-12-02  Cliente32  ProductoC         3     60  Tienda Física
# 32  2023-12-03  Cliente33  ProductoD         1     30         Online
# 33  2023-12-04  Cliente34  ProductoA         3     30         Online
# 34  2023-12-05  Cliente35  ProductoB         2     30         Online
# 35  2023-12-06  Cliente36  ProductoC         5    100  Tienda Física
# 36  2023-12-07  Cliente37  ProductoD         4    120         Online
# 37  2023-12-08  Cliente38  ProductoA         2     20         Online
# 38  2023-12-09  Cliente39  ProductoB         3     45         Online
# 39  2023-12-10  Cliente40  ProductoC         1     20  Tienda Física
# 40  2023-12-11  Cliente41  ProductoD         5    150         Online
# 41  2023-12-12  Cliente42  ProductoA         4     40         Online
# 42  2023-12-13  Cliente43  ProductoB         2     30         Online
# 43  2023-12-14  Cliente44  ProductoC         3     60  Tienda Física
# 44  2023-12-15  Cliente45  ProductoD         2     60         Online
# 45  2023-12-16  Cliente46  ProductoA         1     10         Online
# 46  2023-12-17  Cliente47  ProductoB         5     75         Online
# 47  2023-12-18  Cliente48  ProductoC         4     80  Tienda Física
# 48  2023-12-19  Cliente49  ProductoD         3     90         Online
# 49  2023-12-20  Cliente50  ProductoA         2     20         Online

# %% [markdown]
# # **SELECCIÓN DE COLUMNAS**

# %%
#SELECCIONAR UNA COLUMNA

#AMBAS FORMAS REALIZAN LA MISMA OPERACIÓN
df1['Solicita']
df1.Solicita
# Out:
# 0         Unidad Operación Mantenimiento Provisión Aguas
# 1         Unidad Operación Mantenimiento Provisión Aguas
# 2       Unidad Gestión Infraestructura Agua y Saneamient
# 3        Unidad Desarrollo de Intervenciones de Inversió
# 4         Unidad Operación Mantenimiento Provisión Aguas
#                              ...
# 951    Dirección Proyectos Agua, Saneamiento, Gas y l...
# 952       Unidad Operación Mantenimiento Provisión Aguas
# 953       Unidad Operación Mantenimiento Provisión Aguas
# 954       Unidad Operación Mantenimiento Provisión Aguas
# 955       Unidad Operación Mantenimiento Provisión Aguas
# Name: Solicita, Length: 956, dtype: object

# %%
#SELECCION MÚLTIPLE DE COLUMNAS

#AL SELECCIONAR VARIAS COLUMNAS, TIENES LA OPORTUNIDAD DE CREAR UN NUEVO DATASET A PARTIR DE LAS COLUMNAS SELECCIONADAS
df3 = df2[['Cliente', 'Total', 'Origen']]

# %%
df3
# Out:
#       Cliente  Total         Origen
# 0    Cliente1     50         Online
# 1    Cliente2     45         Online
# 2    Cliente3     40         Online
# 3    Cliente4     40  Tienda Física
# 4    Cliente5     30         Online
# 5    Cliente6     30         Online
# 6    Cliente7     30  Tienda Física
# 7    Cliente8     40         Online
# 8    Cliente9    120         Online
# 9   Cliente10     30  Tienda Física
# 10  Cliente11     75         Online
# 11  Cliente12     40         Online
# 12  Cliente13     30  Tienda Física
# 13  Cliente14     30         Online
# 14  Cliente15     60         Online
# 15  Cliente16     40  Tienda Física
# 16  Cliente17     90         Online
# 17  Cliente18     40         Online
# 18  Cliente19     30  Tienda Física
# 19  Cliente20     60         Online
# 20  Cliente21     30         Online
# 21  Cliente22     50  Tienda Física
# 22  Cliente23     45         Online
# 23  Cliente24     40         Online
# 24  Cliente25    120  Tienda Física
# 25  Cliente26     30         Online
# 26  Cliente27     75         Online
# 27  Cliente28     40         Online
# 28  Cliente29     30  Tienda Física
# 29  Cliente30     20         Online
# 30  Cliente31     60         Online
# 31  Cliente32     60  Tienda Física
# 32  Cliente33     30         Online
# 33  Cliente34     30         Online
# 34  Cliente35     30         Online
# 35  Cliente36    100  Tienda Física
# 36  Cliente37    120         Online
# 37  Cliente38     20         Online
# 38  Cliente39     45         Online
# 39  Cliente40     20  Tienda Física
# 40  Cliente41    150         Online
# 41  Cliente42     40         Online
# 42  Cliente43     30         Online
# 43  Cliente44     60  Tienda Física
# 44  Cliente45     60         Online
# 45  Cliente46     10         Online
# 46  Cliente47     75         Online
# 47  Cliente48     80  Tienda Física
# 48  Cliente49     90         Online
# 49  Cliente50     20         Online

# %%
#SELECCION POR POSICIÓN

df3.iloc[0:0]
# Out:
# Empty DataFrame
# Columns: [Cliente, Total, Origen]
# Index: []

# %%
#SELECCION POR ETIQUETA
df3.loc[0:0]
# Out:
#     Cliente  Total  Origen
# 0  Cliente1     50  Online

# %%
#SELECCION CON CONDICIÓN

#PERMITE APLICAR FILTROS SEGÚN LA NECESIDAD A BUSCAR EN EL DATAFRAME
seleccion = df3[df3['Total']> 40]
seleccion.count()
# Out:
# Cliente    22
# Total      22
# Origen     22
# dtype: int64

# %% [markdown]
# # **FILTRADO Y VISUALIZACIÓN DE DATOS**

# %%
df2
# Out:
#          Fecha    Cliente   Producto  Cantidad  Precio Unitario  Total  \
# 0   2023-11-01   Cliente1  ProductoA         5               10     50
# 1   2023-11-02   Cliente2  ProductoB         3               15     45
# 2   2023-11-03   Cliente3  ProductoC         2               20     40
# 3   2023-11-04   Cliente4  ProductoA         4               10     40
# 4   2023-11-05   Cliente5  ProductoD         1               30     30
# 5   2023-11-06   Cliente6  ProductoB         2               15     30
# 6   2023-11-07   Cliente7  ProductoA         3               10     30
# 7   2023-11-08   Cliente8  ProductoC         2               20     40
# 8   2023-11-09   Cliente9  ProductoD         4               30    120
# 9   2023-11-10  Cliente10  ProductoA         3               10     30
# 10  2023-11-11  Cliente11  ProductoB         5               15     75
# 11  2023-11-12  Cliente12  ProductoC         2               20     40
# 12  2023-11-13  Cliente13  ProductoD         1               30     30
# 13  2023-11-14  Cliente14  ProductoA         3               10     30
# 14  2023-11-15  Cliente15  ProductoB         4               15     60
# 15  2023-11-16  Cliente16  ProductoC         2               20     40
# 16  2023-11-17  Cliente17  ProductoD         3               30     90
# 17  2023-11-18  Cliente18  ProductoA         4               10     40
# 18  2023-11-19  Cliente19  ProductoB         2               15     30
# 19  2023-11-20  Cliente20  ProductoC         3               20     60
# 20  2023-11-21  Cliente21  ProductoD         1               30     30
# 21  2023-11-22  Cliente22  ProductoA         5               10     50
# 22  2023-11-23  Cliente23  ProductoB         3               15     45
# 23  2023-11-24  Cliente24  ProductoC         2               20     40
# 24  2023-11-25  Cliente25  ProductoD         4               30    120
# 25  2023-11-26  Cliente26  ProductoA         3               10     30
# 26  2023-11-27  Cliente27  ProductoB         5               15     75
# 27  2023-11-28  Cliente28  ProductoC         2               20     40
# 28  2023-11-29  Cliente29  ProductoD         1               30     30
# 29  2023-11-30  Cliente30  ProductoA         2               10     20
# 30  2023-12-01  Cliente31  ProductoB         4               15     60
# 31  2023-12-02  Cliente32  ProductoC         3               20     60
# 32  2023-12-03  Cliente33  ProductoD         1               30     30
# 33  2023-12-04  Cliente34  ProductoA         3               10     30
# 34  2023-12-05  Cliente35  ProductoB         2               15     30
# 35  2023-12-06  Cliente36  ProductoC         5               20    100
# 36  2023-12-07  Cliente37  ProductoD         4               30    120
# 37  2023-12-08  Cliente38  ProductoA         2               10     20
# 38  2023-12-09  Cliente39  ProductoB         3               15     45
# 39  2023-12-10  Cliente40  ProductoC         1               20     20
# 40  2023-12-11  Cliente41  ProductoD         5               30    150
# 41  2023-12-12  Cliente42  ProductoA         4               10     40
# 42  2023-12-13  Cliente43  ProductoB         2               15     30
# 43  2023-12-14  Cliente44  ProductoC         3               20     60
# 44  2023-12-15  Cliente45  ProductoD         2               30     60
# 45  2023-12-16  Cliente46  ProductoA         1               10     10
# 46  2023-12-17  Cliente47  ProductoB         5               15     75
# 47  2023-12-18  Cliente48  ProductoC         4               20     80
# 48  2023-12-19  Cliente49  ProductoD         3               30     90
# 49  2023-12-20  Cliente50  ProductoA         2               10     20
#
#            Origen
# 0          Online
# 1          Online
# 2          Online
# 3   Tienda Física
# 4          Online
# 5          Online
# 6   Tienda Física
# 7          Online
# 8          Online
# 9   Tienda Física
# 10         Online
# 11         Online
# 12  Tienda Física
# 13         Online
# 14         Online
# 15  Tienda Física
# 16         Online
# 17         Online
# 18  Tienda Física
# 19         Online
# 20         Online
# 21  Tienda Física
# 22         Online
# 23         Online
# 24  Tienda Física
# 25         Online
# 26         Online
# 27         Online
# 28  Tienda Física
# 29         Online
# 30         Online
# 31  Tienda Física
# 32         Online
# 33         Online
# 34         Online
# 35  Tienda Física
# 36         Online
# 37         Online
# 38         Online
# 39  Tienda Física
# 40         Online
# 41         Online
# 42         Online
# 43  Tienda Física
# 44         Online
# 45         Online
# 46         Online
# 47  Tienda Física
# 48         Online
# 49         Online

# %%
#VENTAS POR ORIGEN (MONEDA)

Total_Online = df2[df2.Origen.isin(['Online'])]
VO= sum(Total_Online['Total'])
print("Ventas ONLINE --->",VO)

Total_Fisica = df2[df2.Origen.isin(['Tienda Física'])]
VF = sum(Total_Fisica['Total'])
print("Ventas TIENDA FISICA --->",VF)

x = ['Online','Fisica']
y = [VO,VF]

fig, ax= plt.subplots()

ax.bar(x,y,linewidth=5)
# Out:
# Ventas ONLINE ---> 1840
# Ventas TIENDA FISICA ---> 720
# <BarContainer object of 2 artists>

# %%
TotalesOrigen = df2[['Origen','Total']]
TotalesOrigen2 = TotalesOrigen.groupby(by=['Origen']).sum()
TotalesOrigen2

fig, ax = plt.subplots()
valores = TotalesOrigen2.Total
titulosm = df2['Origen'].unique()
colores = ["#619cff", "#00ba38"]
ax.bar(x=titulosm, height = valores, color=colores)
# Out:
# <BarContainer object of 2 artists>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha            50 non-null     object
#  1   Cliente          50 non-null     object
#  2   Producto         50 non-null     object
#  3   Cantidad         50 non-null     int64
#  4   Precio Unitario  50 non-null     int64
#  5   Total            50 non-null     int64
#  6   Origen           50 non-null     object
# dtypes: int64(3), object(4)
# memory usage: 2.9+ KB

# %%
cantidad = df2[df2['Origen']=='Online']
A = cantidad['Origen'].count()

cantidad2 = df2[df2['Origen']=='Tienda Física']
B = cantidad2['Origen'].count()

print("Total de ventas online",A)
print("Total de ventas tienda física",B)
# Out:
# Total de ventas online 36
# Total de ventas tienda física 14

# %%
cantidadO = df2[df2.Origen.isin(['Online'])]
TO = cantidadO['Total'].count()
print("Ventas Online --->", TO)

cantidadT = df2[df2.Origen.isin(['Tienda Física'])]
TF = cantidadT['Total'].count()
print("Ventas Fisicas --->", TF)

#VALORES A UTILIZAR DE LOS CÁLCULOS
TITULOS = df2["Origen"].unique()
DATOS = [TO,TF]
fig, ax = plt.subplots()
explode = [0.1,0]
ax.pie(DATOS,labels = TITULOS, explode = explode, autopct = '%1.1f%%')
# Out:
# Ventas Online ---> 36
# Ventas Fisicas ---> 14
# ([<matplotlib.patches.Wedge at 0x7ec4574c4b80>,
#   <matplotlib.patches.Wedge at 0x7ec457899bd0>],
#  [Text(-0.7649088708044604, 0.9246158225796516, 'Online'),
#   Text(0.7011665442588013, -0.8475644383834013, 'Tienda Física')],
#  [Text(-0.44619684130260184, 0.53935922983813, '72.0%'),
#   Text(0.38245447868661886, -0.4623078754818552, '28.0%')])

# %%
dftotales = df2[['Producto','Total']]
dftotales2 = dftotales.groupby(by=['Producto']).sum()
dftotales2
# Out:
#            Total
# Producto
# ProductoA    440
# ProductoB    600
# ProductoC    620
# ProductoD    900

# %%
df22 = df2.groupby(['Producto'])['Total'].transform('sum').unique()
fig,ax = plt.subplots()
labelsP = df2['Producto'].unique()

ax.pie(df22,labels = labelsP, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ec457141c60>,
#   <matplotlib.patches.Wedge at 0x7ec45753a800>,
#   <matplotlib.patches.Wedge at 0x7ec457142950>,
#   <matplotlib.patches.Wedge at 0x7ec457142fe0>],
#  [Text(0.9435014710002994, 0.5655130186125439, 'ProductoA'),
#   Text(-0.26727819789359025, 1.0670343785139984, 'ProductoB'),
#   Text(-1.0838054066278355, -0.1880580776363311, 'ProductoC'),
#   Text(0.4945724626200673, -0.982546731315067, 'ProductoD')],
#  [Text(0.5146371660001633, 0.308461646515933, '17.2%'),
#   Text(-0.14578810794195832, 0.5820187519167264, '23.4%'),
#   Text(-0.5911665854333648, -0.10257713325618058, '24.2%'),
#   Text(0.26976679779276397, -0.5359345807173092, '35.2%')])

# %%
sns.relplot(data = df2, x='Cantidad', y = 'Total', hue = 'Origen', style = "Origen")

# %%
sns.displot(df2, x='Total')

# %%
sns.regplot(x = "Total", y='Cantidad', data = df2)
# Out:
# <Axes: xlabel='Total', ylabel='Cantidad'>

# %%
sns.scatterplot(x=df2.Cantidad, y = df2.Total)
# Out:
# <Axes: xlabel='Cantidad', ylabel='Total'>

# %%
pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 60.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (3.7.1)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (4.66.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (1.11.4)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: importlib-resources>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (6.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Installing collected packages: sweetviz
# Successfully installed sweetviz-2.3.1

# %%
import sweetviz as sv
report = sv.analyze(df2)
report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(ie,e){&quot;use strict&quot;;var oe=[],r=Object.getPrototypeOf,ae=oe.slice,g=oe.flat?function(e){return oe.flat.call(e)}:function(e){return oe.concat.apply([],e)},s=oe.push,se=oe.indexOf,n={},i=n.toString,ue=n.hasOwnProperty,o=ue.toString,a=o.call(Object),le={},v=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},y=function(e){return null!=e&amp;&amp;e===e.window},C=ie.document,u={type:!0,src:!0,nonce:!0,noModule:!0};function m(e,t,n){var r,i,o=(n=n||C).createElement(&quot;script&quot;);if(o.text=e,t)for(r in u)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function x(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[i.call(e)]||&quot;object&quot;:typeof e}var t=&quot;3.7.1&quot;,l=/HTML$/i,ce=function(e,t){return new ce.fn.init(e,t)};function c(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=x(e);return!v(e)&amp;&amp;!y(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}function fe(e,t){return e.nodeName&amp;&amp;e.nodeName.toLowerCase()===t.toLowerCase()}ce.fn=ce.prototype={jquery:t,constructor:ce,length:0,toArray:function(){return ae.call(this)},get:function(e){return null==e?ae.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=ce.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return ce.each(this,e)},map:function(n){return this.pushStack(ce.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(ae.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(ce.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(ce.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:s,sort:oe.sort,splice:oe.splice},ce.extend=ce.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||v(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(ce.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||ce.isPlainObject(n)?n:{},i=!1,a[t]=ce.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},ce.extend({expando:&quot;jQuery&quot;+(t+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==i.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=ue.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;o.call(n)===a)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){m(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(c(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},text:function(e){var t,n=&quot;&quot;,r=0,i=e.nodeType;if(!i)while(t=e[r++])n+=ce.text(t);return 1===i||11===i?e.textContent:9===i?e.documentElement.textContent:3===i||4===i?e.nodeValue:n},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(c(Object(e))?ce.merge(n,&quot;string&quot;==typeo ...
